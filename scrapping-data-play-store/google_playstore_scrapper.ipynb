# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
# # INI DIGUNAKAN KETIKA KAMU INGIN SCRAPPING SEMUA DATA DI PLAYSTORE
# #JANGAN DI RUN KODE INI, KECUALI ANDA INGIN SCRAPE SEMUA REVIEWS SEKALIGUS

# from google_play_scraper import Sort, reviews_all

# result = reviews_all(
#     'com.bukalapak.android',
#     sleep_milliseconds=0, # defaults to 0
#     lang='id', # defaults to 'en'
#     country='id', # defaults to 'us'
#     sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT , you can use Sort.NEWEST to get newst reviews
# )

# %%
#Run kode ini jika ingin scrape data dengan jumlah tertentu. Ganti (misal, ingin scrape sejumlah 1000, maka ganti kode , count = 1000 )

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.mobile.legends', # link yang mau di scrapping
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # sortir berdasarkan terbaru atau relevan atau rating
    count=200, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId          userName  \
# 0  66728e65-c18b-4c04-92fb-d7642a3bc5ed       Aryan Fikri
# 1  3091b2ee-4747-420e-9f66-41f467b5c713       Najwa Putri
# 2  1452eb7c-c741-4f93-8e6c-cf2f77d24314  Louise Prasticia
# 3  d11d2c3c-3e24-45e2-9f42-851c25e071fc        Jehan Dila
# 4  34531de8-1cc9-410c-b0ad-0bdc177005e5       Ahmad Darul
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  Halo min, saya kasih bintang 4 untuk game ini....      4             44
# 1  Sejauh ini gamenya tidak buruk atau semacam ny...      5           8580
# 2  gamenya si sejauh ini oke aja dari segi grafik...      4            206
# 3  Makin kesini makin buruk gamenya,mulai dari da...      1          13209
# 4  Menurut saya pribadi yg harus diperbaiki yaitu...      5           5733
#
#   reviewCreatedVersion                  at replyContent repliedAt   appVersion
# 0          1.8.93.9702 2024-06-25 12:04:05         None       NaT  1.8.93.9702
# 1          1.8.92.9701 2024-06-19 06:23:06         None       NaT  1.8.92.9701
# 2          1.8.92.9701 2024-06-24 10:57:41         None       NaT  1.8.92.9701
# 3          1.8.92.9701 2024-06-20 16:32:15         None       NaT  1.8.92.9701
# 4          1.8.92.9701 2024-06-20 23:18:46         None       NaT  1.8.92.9701

# %%
len(df_busu.index) #count the number of data we got
# Out:
# 200

# %%
df_busu[['userName', 'score','at', 'content']].head()  #preview userName, rating, date-time, and reviews only
# Out:
#            userName  score                  at  \
# 0       Aryan Fikri      4 2024-06-25 12:04:05
# 1       Najwa Putri      5 2024-06-19 06:23:06
# 2  Louise Prasticia      4 2024-06-24 10:57:41
# 3        Jehan Dila      1 2024-06-20 16:32:15
# 4       Ahmad Darul      5 2024-06-20 23:18:46
#
#                                              content
# 0  Halo min, saya kasih bintang 4 untuk game ini....
# 1  Sejauh ini gamenya tidak buruk atau semacam ny...
# 2  gamenya si sejauh ini oke aja dari segi grafik...
# 3  Makin kesini makin buruk gamenya,mulai dari da...
# 4  Menurut saya pribadi yg harus diperbaiki yaitu...

# %%
#Run This Code to Sort the Data By Date

new_df = df_busu[['userName', 'score','at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#                     userName  score                  at  \
# 7    Pandu Pramana Putra 8.7      1 2024-06-25 13:17:23
# 103             Gisel Ananta      5 2024-06-25 12:53:16
# 60        parawiga jaya guna      1 2024-06-25 12:35:22
# 0                Aryan Fikri      4 2024-06-25 12:04:05
# 15              Fawwaz Dzaky      1 2024-06-25 12:02:50
#
#                                                content
# 7    Menurut saya lebih perbaiki sistem game pertan...
# 103  monton tolong bantu saya dengan cara mempermud...
# 60   Sering banget lelet..tiba2 aja lambat dalam ma...
# 0    Halo min, saya kasih bintang 4 untuk game ini....
# 15   Kalo menurut saya game ini tu banyak minus nya...

# %%
my_df = sorted_df[['userName', 'score','at', 'content']] #get userName, rating, date-time, and reviews only

# %%
my_df.head()
# Out:
#                     userName  score                  at  \
# 7    Pandu Pramana Putra 8.7      1 2024-06-25 13:17:23
# 103             Gisel Ananta      5 2024-06-25 12:53:16
# 60        parawiga jaya guna      1 2024-06-25 12:35:22
# 0                Aryan Fikri      4 2024-06-25 12:04:05
# 15              Fawwaz Dzaky      1 2024-06-25 12:02:50
#
#                                                content
# 7    Menurut saya lebih perbaiki sistem game pertan...
# 103  monton tolong bantu saya dengan cara mempermud...
# 60   Sering banget lelet..tiba2 aja lambat dalam ma...
# 0    Halo min, saya kasih bintang 4 untuk game ini....
# 15   Kalo menurut saya game ini tu banyak minus nya...

# %%
my_df.to_csv("scrapped_data.csv", index = False)  #Save the file as CSV , to download: click the folder icon on the left. the csv file should be there.
